# %%
# %config Completer.use_jedi = False
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir('../')

# %%
from src.Webcam import Webcam

# %%
webcam=Webcam(device_id=0,stream_name='Webcam',fps=30)

# %%
webcam.start()

# %%
webcam.get_current_frame(frame_size=(640,260))
# Out:
# <PIL.Image.Image image mode=RGB size=640x260 at 0x28ABED4A730>

# %%
webcam.start_recording(output_path='output',frame_size=(840,260))

# %%
webcam.stop_recording()

# %%
webcam.stop()
